# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    title = state['title']

    prompt = f"Generate a detailed outline for a blog on the topic - {title}"
    outline = model.invoke(prompt).content

    state['outline'] = outline

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f"Write a detailed blog on the title - {title} using the following outline \n {outline}"
    content = model.invoke(prompt).content

    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)


graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI in india'}
initial_state = {
    "title": "Rise of AI in india",
    "outline": "",
    "content": ""
}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of AI in india', 'outline': '', 'content': '## The Rise of AI in India: A Technological Revolution Unfolding\n\nArtificial Intelligence (AI) is no longer a futuristic concept; it\'s a tangible force reshaping industries, economies, and our daily lives. And in India, this transformative wave is not just arriving, it\'s surging. From bustling metropolises to remote villages, AI is rapidly weaving itself into the fabric of the nation, promising unprecedented growth and innovation. This blog post delves into the burgeoning landscape of AI in India, exploring its current impact, the driving forces behind its ascent, the challenges it faces, and the bright future it holds.\n\n### 1. Introduction: The AI Awakening in India\n\nFor years, India has been a powerhouse of technological talent, particularly in the IT sector. However, the recent surge in AI adoption marks a significant evolution. It\'s a transition from being a service provider to becoming a creator and innovator in the AI space. This "AI awakening" is fueled by a confluence of factors, including a massive digital infrastructure push, a growing pool of skilled professionals, and a government actively championing technological advancement. India is no longer just consuming AI; it\'s actively building, deploying, and shaping its future.\n\n### 2. The Current Landscape: AI Across Indian Sectors\n\nAI\'s influence is no longer confined to niche tech companies. It\'s permeating almost every sector of the Indian economy, driving efficiency, personalization, and new possibilities.\n\n*   **Healthcare:** AI is revolutionizing diagnostics with advanced image analysis for detecting diseases like cancer and diabetic retinopathy. Predictive analytics are helping in disease outbreak prediction and personalized treatment plans. AI-powered chatbots are providing accessible health information and preliminary consultations, especially in remote areas.\n*   **Agriculture:** With a significant portion of India\'s population reliant on agriculture, AI is a game-changer. Precision farming techniques, powered by AI-driven drones and sensors, optimize irrigation, fertilization, and pest control, leading to increased yields and reduced resource wastage. AI is also being used to predict weather patterns and crop diseases.\n*   **Finance (FinTech):** AI is at the heart of India\'s booming FinTech sector. Fraud detection, risk assessment, credit scoring, and personalized financial advisory services are all being enhanced by AI algorithms. Chatbots are improving customer service and accessibility for financial products.\n*   **E-commerce & Retail:** The personalized recommendations that drive online shopping are a prime example of AI in action. AI is also optimizing supply chains, managing inventory, and enhancing customer experiences through chatbots and virtual assistants.\n*   **Manufacturing:** AI is powering the "Industry 4.0" revolution in India. Predictive maintenance of machinery reduces downtime. AI-driven robots are improving assembly line efficiency and safety. Quality control is being enhanced through AI-powered visual inspection systems.\n*   **Education:** AI is personalizing learning experiences through adaptive learning platforms. AI-powered tools are assisting educators with grading and administrative tasks, allowing them to focus more on teaching. Virtual tutors and language learning apps are also gaining traction.\n*   **Smart Cities & Governance:** AI is a key enabler for India\'s smart city initiatives. Traffic management systems, waste management optimization, and resource allocation are all being improved with AI. AI is also being explored for enhancing public service delivery and citizen engagement.\n\n### 3. Driving Forces Behind India\'s AI Ascent\n\nSeveral key factors are propelling India\'s AI journey:\n\n*   **Digital India & Infrastructure:** The government\'s ambitious "Digital India" initiative has laid a robust foundation of digital infrastructure. Wid ...
